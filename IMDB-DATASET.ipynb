# %%
#Pandas'ı import edelim
import pandas as pd

# %%
#Veriyi okutalım
data=pd.read_csv('data.csv')

# %%
#Tüm verilere göz atalım
data
# Out:
#              id               title                   genres  averageRating  \
# 0     tt0903747        Breaking Bad   Crime, Drama, Thriller            9.5
# 1     tt5491994     Planet Earth II              Documentary            9.5
# 2     tt0185906    Band of Brothers      Drama, History, War            9.4
# 3     tt0795176        Planet Earth      Documentary, Family            9.4
# 4     tt5152226        Tree of Life                    Drama            9.4
# ..          ...                 ...                      ...            ...
# 995   tt5368542        The Exorcist   Drama, Horror, Mystery            7.9
# 996  tt11379026              Ghosts          Comedy, Fantasy            7.9
# 997  tt14824792                 Ted                   Comedy            7.9
# 998   tt2262532         The Fosters           Drama, Romance            7.9
# 999   tt1985443  Hatfields & McCoys  Drama, History, Romance            7.9
#
#      numVotes  releaseYear
# 0     2222284         2008
# ...

# %%
#İlk 10 veriye bakalım
data.head(10)
# Out:
#            id                       title                        genres  \
# 0   tt0903747                Breaking Bad        Crime, Drama, Thriller
# 1   tt5491994             Planet Earth II                   Documentary
# 2   tt0185906            Band of Brothers           Drama, History, War
# 3   tt0795176                Planet Earth           Documentary, Family
# 4   tt5152226                Tree of Life                         Drama
# 5   tt7366338                   Chernobyl      Drama, History, Thriller
# 6   tt0306414                    The Wire        Crime, Drama, Thriller
# 7   tt0417299  Avatar: The Last Airbender  Action, Adventure, Animation
# 8  tt30263074           Sapne Vs Everyone                         Drama
# 9   tt6769208              Blue Planet II                   Documentary
#
#    averageRating  numVotes  releaseYear
# 0            9.5   2222284         2008
# 1            9.5    161331         2016
# 2            9.4    543090         2001
# ...

# %%
#Elimizdeki verilerin tiplerine bakalım
data.dtypes
# Out:
# id                object
# title             object
# genres            object
# averageRating    float64
# numVotes           int64
# releaseYear        int64
# dtype: object

# %%
#Veri hakkında bilgiler alalım
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   object
#  1   title          1000 non-null   object
#  2   genres         1000 non-null   object
#  3   averageRating  1000 non-null   float64
#  4   numVotes       1000 non-null   int64
#  5   releaseYear    1000 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 47.0+ KB

# %%
#Drama türündeki filmlere bakalım
genres_drama=data[data["genres"]=="Drama"]
genres_drama
# Out:
#              id                       title genres  averageRating  numVotes  \
# 4     tt5152226                Tree of Life  Drama            9.4     11606
# 8    tt30263074           Sapne Vs Everyone  Drama            9.3     70742
# 15   tt14392248                   Aspirants  Drama            9.2    313487
# 29   tt28227737              Sandeep Bhaiya  Drama            9.1     75816
# 51   tt21279678                    NCR Days  Drama            9.0     43879
# 72    tt0200276               The West Wing  Drama            8.9     87800
# 75    tt0092337                     Dekalog  Drama            8.9     28456
# 83   tt11992526                       Harga  Drama            8.9     10016
# 127   tt0804503                     Mad Men  Drama            8.7    266680
# 171  tt11007006                       Azize  Drama            8.7     13683
# 174   tt7621364                 Black Pearl  Drama            8.7     12925
# ...

# %%
#Drama türündeki filmlerin ortalama oylarına bakalım
drama=data[data['genres']=="Drama"].averageRating.mean()
drama
# Out:
# 8.422

# %%
#Oyu 9 üzeri filmlere bakalım
films=data[data['averageRating']>9.0]
films.head()
# Out:
#           id             title                  genres  averageRating  \
# 0  tt0903747      Breaking Bad  Crime, Drama, Thriller            9.5
# 1  tt5491994   Planet Earth II             Documentary            9.5
# 2  tt0185906  Band of Brothers     Drama, History, War            9.4
# 3  tt0795176      Planet Earth     Documentary, Family            9.4
# 4  tt5152226      Tree of Life                   Drama            9.4
#
#    numVotes  releaseYear
# 0   2222284         2008
# 1    161331         2016
# 2    543090         2001
# 3    222856         2006
# 4     11606         2014

# %%
#Veri boyutunu inceleyelim
data.shape
# Out:
# (1000, 6)

# %%
#Eksik kayıp verimiz var mı bakalım
data.isnull().sum()
# Out:
# id               0
# title            0
# genres           0
# averageRating    0
# numVotes         0
# releaseYear      0
# dtype: int64

# %% [markdown]
# Eksik veya kayıp verimiz yok

# %%
#Verilerimizin istatiksel özetlerini alalım
data.describe()
# Out:
#        averageRating      numVotes  releaseYear
# count    1000.000000  1.000000e+03  1000.000000
# mean        8.367500  9.192366e+04  2010.210000
# std         0.322238  1.732035e+05    12.332396
# min         7.900000  1.001000e+04  1951.000000
# 25%         8.100000  1.787525e+04  2005.000000
# 50%         8.300000  3.425400e+04  2014.000000
# 75%         8.600000  9.044375e+04  2019.000000
# max         9.500000  2.356835e+06  2024.000000

# %%
#İstatistige bakarak 9.5 en yüksek oy değerimiz peki bu hangi film veya filmler
film_oy=data[data['averageRating']==9.5]
film_oy
# Out:
#           id            title                  genres  averageRating  \
# 0  tt0903747     Breaking Bad  Crime, Drama, Thriller            9.5
# 1  tt5491994  Planet Earth II             Documentary            9.5
#
#    numVotes  releaseYear
# 0   2222284         2008
# 1    161331         2016

# %%
#Listede 2024 yılına ait filmleri listeyelim
güncel_film=data[data['releaseYear']==2024]
güncel_film
# Out:
#              id                                title  \
# 105  tt15435876                          The Penguin
# 106  tt16026746                            X-Men '97
# 190   tt2788316                               Shogun
# 256  tt31862849                       Very Parivarik
# 353  tt27867155         Mr Bates vs. The Post Office
# 366  tt12637874                              Fallout
# 523  tt21209876                        Solo Leveling
# 568  tt21975436                          Kaiju No. 8
# 677  tt27668559                       Queen of Tears
# 732  tt16283804                              One Day
# 733  tt11016042                               Ripley
# 839  tt13210838                        The Gentlemen
# 876  tt26933824                    Nobody Wants This
# 904  tt28681409           Ranneeti: Balakot & Beyond
# 943  tt27411674                         Shekhar Home
# 946   tt9022422           The Tattooist of Auschwitz
# 992   tt9859436  The Walking Dead: The Ones Who Live
# ...

# %%
#2024 yılına ait filmlerin oy sayılarının ortalamasını alalım
ortalama_güncel_film=data[data['releaseYear']==2024]['numVotes'].mean()
ortalama_güncel_film
# Out:
# 54872.77777777778

# %%
#Ve bu güncel filmlerin skor deger ortalamasını alalım
ort=data[data['releaseYear']==2024]['averageRating'].mean()
ort
# Out:
# 8.25

# %%
#Hangi türden kaç film var:
data.genres.value_counts()
# Out:
# Action, Adventure, Animation       95
# Comedy                             80
# Crime, Drama, Mystery              70
# Comedy, Drama                      55
# Drama                              50
#                                    ..
# Animation, Documentary, History     1
# Animation, Drama, Mystery           1
# Comedy, Horror                      1
# Comedy, Sport, Talk-Show            1
# Adventure, Drama, Horror            1
# Name: genres, Length: 186, dtype: int64

# %%
count = (data[data['genres'] == "Comedy"]['averageRating'] > 8.5).value_counts()
count
# Out:
# False    53
# True     27
# Name: averageRating, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
#En yüksek puanlı 10 film
top_rated_movies=data.nlargest(10,'averageRating')
top_rated_movies
# Out:
#            id                       title                        genres  \
# 0   tt0903747                Breaking Bad        Crime, Drama, Thriller
# 1   tt5491994             Planet Earth II                   Documentary
# 2   tt0185906            Band of Brothers           Drama, History, War
# 3   tt0795176                Planet Earth           Documentary, Family
# 4   tt5152226                Tree of Life                         Drama
# 5   tt7366338                   Chernobyl      Drama, History, Thriller
# 6   tt0306414                    The Wire        Crime, Drama, Thriller
# 7   tt0417299  Avatar: The Last Airbender  Action, Adventure, Animation
# 8  tt30263074           Sapne Vs Everyone                         Drama
# 9   tt6769208              Blue Planet II                   Documentary
#
#    averageRating  numVotes  releaseYear
# 0            9.5   2222284         2008
# 1            9.5    161331         2016
# 2            9.4    543090         2001
# ...

# %%
movies_year=data['releaseYear'].value_counts().sort_index()
movies_year.plot(kind='line')
# Out:
# <Axes: >

# %%
puan_dagılımı=data['averageRating'].plot(kind='hist',bins=20)

# %%
#Türlere göre ortalama oy sayısı
tür_ort=data.groupby('genres')['numVotes'].mean()
tür_ort
# Out:
# genres
# Action                           16722.000000
# Action, Adventure, Animation     68105.052632
# Action, Adventure, Biography    204397.500000
# Action, Adventure, Comedy        78035.666667
# Action, Adventure, Drama        237749.620690
#                                     ...
# Fantasy, Mystery, Romance        17056.000000
# Fantasy, War                     14193.000000
# Game-Show, Reality-TV            15781.666667
# Reality-TV                       16546.500000
# Thriller                         14621.000000
# Name: numVotes, Length: 186, dtype: float64

# %%
#Türlere göre ortalama oy sayısı
tür = data.groupby('genres')['averageRating'].mean()
tür
# Out:
# genres
# Action                          8.000000
# Action, Adventure, Animation    8.430526
# Action, Adventure, Biography    8.500000
# Action, Adventure, Comedy       8.166667
# Action, Adventure, Drama        8.317241
#                                   ...
# Fantasy, Mystery, Romance       8.100000
# Fantasy, War                    8.000000
# Game-Show, Reality-TV           8.533333
# Reality-TV                      8.400000
# Thriller                        8.100000
# Name: averageRating, Length: 186, dtype: float64

# %%
#2024 yılındaki TOP10 dizi veya filmi alalım
top_2024=data[data['releaseYear']==2024].nlargest(10,'averageRating')
top_2024
# Out:
#              id                         title                        genres  \
# 105  tt15435876                   The Penguin                  Crime, Drama
# 106  tt16026746                     X-Men '97  Action, Adventure, Animation
# 190   tt2788316                        Shogun     Adventure, Drama, History
# 256  tt31862849                Very Parivarik                        Comedy
# 353  tt27867155  Mr Bates vs. The Post Office              Biography, Drama
# 366  tt12637874                       Fallout      Action, Adventure, Drama
# 523  tt21209876                 Solo Leveling  Action, Adventure, Animation
# 568  tt21975436                   Kaiju No. 8  Action, Adventure, Animation
# 677  tt27668559                Queen of Tears        Drama, Family, Romance
# 732  tt16283804                       One Day        Comedy, Drama, Romance
#
#      averageRating  numVotes  releaseYear
# 105            8.8     42636         2024
# 106            8.8     36799         2024
# ...

# %%
#Peki listenin son 10'una bakalım
data.tail(10)
# Out:
#              id                                title  \
# 990   tt8543390                          Modern Love
# 991   tt1255913                       Bored to Death
# 992   tt9859436  The Walking Dead: The Ones Who Live
# 993   tt1958961                           Lilyhammer
# 994   tt8910922                      Solar Opposites
# 995   tt5368542                         The Exorcist
# 996  tt11379026                               Ghosts
# 997  tt14824792                                  Ted
# 998   tt2262532                          The Fosters
# 999   tt1985443                   Hatfields & McCoys
#
#                            genres  averageRating  numVotes  releaseYear
# 990        Comedy, Drama, Romance            7.9     37452         2019
# 991          Comedy, Crime, Drama            7.9     34927         2009
# 992       Drama, Horror, Thriller            7.9     34789         2024
# 993          Comedy, Crime, Drama            7.9     32868         2012
# ...
